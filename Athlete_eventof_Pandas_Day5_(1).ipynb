# %% [markdown]
# ## Day 2 of Pandas

# %% [markdown]
# ### <font color=blue>Some basic data steps/functions</font>

# %%
import pandas as pd
athlete_data=pd.read_csv('athlete_events.csv')

# %%
athlete_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# find the top 5 rows of your data
athlete_data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# find the last 5 rows of your data
athlete_data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
#Drop duplicates
athlete_data=athlete_data.drop_duplicates()
athlete_data.reset_index(inplace=True, drop=True)
athlete_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 269726  135569                Andrzej ya   M  29.0   179.0    89.0
# 269727  135570                  Piotr ya   M  27.0   176.0    59.0
# 269728  135570                  Piotr ya   M  27.0   176.0    59.0
# 269729  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 269730  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Checking for Null values
athlete_data.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
set(athlete_data['Medal'])
# Out:
# {'Bronze', 'Gold', 'Silver', nan}

# %% [markdown]
# ## Data Cleaning & Missing Value Handling

# %%
# If the number of entries is N, you have less than 5-10% missing values-- we can eliminate those rows

athlete_data=athlete_data[athlete_data['Age'].notna()]
athlete_data.reset_index(inplace=True, drop=True)

# If the number of entries is N, you have 30-50% missing values-- we can replace the rows with mean, median, mode
athlete_data['Height']=athlete_data['Height'].fillna(athlete_data['Height'].mean())
athlete_data['Weight']=athlete_data['Weight'].fillna(athlete_data['Weight'].mean())
athlete_data['Medal']=athlete_data['Medal'].fillna("None")
athlete_data.reset_index(inplace=True, drop=True)



# #If the number of entries is N, you have above 70% missing values-- Use some intuition and eliminate the column
athlete_data
# Out:
#             ID                      Name Sex   Age      Height     Weight  \
# 0            1                 A Dijiang   M  24.0  180.000000  80.000000
# 1            2                  A Lamusi   M  23.0  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M  24.0  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M  34.0  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F  21.0  185.000000  82.000000
# ...        ...                       ...  ..   ...         ...        ...
# 260411  135569                Andrzej ya   M  29.0  179.000000  89.000000
# 260412  135570                  Piotr ya   M  27.0  176.000000  59.000000
# 260413  135570                  Piotr ya   M  27.0  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M  30.0  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M  34.0  185.000000  96.000000
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
#Drop duplicates again
athlete_data=athlete_data.drop_duplicates()
athlete_data.reset_index(inplace=True, drop=True)
athlete_data
# Out:
#             ID                      Name Sex  Age      Height     Weight  \
# 0            1                 A Dijiang   M   24  180.000000  80.000000
# 1            2                  A Lamusi   M   23  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M   24  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M   34  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F   21  185.000000  82.000000
# ...        ...                       ...  ..  ...         ...        ...
# 260411  135569                Andrzej ya   M   29  179.000000  89.000000
# 260412  135570                  Piotr ya   M   27  176.000000  59.000000
# 260413  135570                  Piotr ya   M   27  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M   30  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M   34  185.000000  96.000000
#
#                   Team        Games            City  \
# ...

# %%
#check column names
athlete_data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# Viewing each column
set(list(athlete_data['Team']))
# Out:
# {'Tango',
#  'Kuwait',
#  'Oman',
#  'Australia/Great Britain',
#  'Yemen',
#  'Persey',
#  'Turkmenistan',
#  'Georgia',
#  'Serbia',
#  'Italy-1',
#  'Puerto Rico-1',
#  'Monaco',
#  'Femur-1',
#  'Indonesia-2',
#  'Kazakhstan',
#  'Uzbekistan',
#  'Faneca',
#  'New York Athletic Club',
#  'Camille',
#  'Anitra',
#  'New York Athletic Club #1-1',
#  'Pupilles de Neptune de Lille #1-3',
#  'Uzbekistan-1',
#  'Syndi',
#  'Sidi-Fekkar-14',
#  'Omilos Ereton Smyrnis',
#  'Belgium',
#  'Lbeck',
#  'Hi-Hi',
#  'Botswana',
#  'Kuling',
#  'USFSA',
#  'Latvia',
#  'Armenia',
#  'Mauritania',
#  'Elvis Va',
#  'East Germany-3',
#  'Sans Atout-1',
#  'Leander Club-2',
#  'Zut',
#  'Whirlaway',
#  'Portugal-1',
#  'Laurea-1',
#  'Thailand-2',
#  'Espuma del Mar',
#  'Bona Fide',
#  'Trintel II',
#  'Ral-Club Barcelona',
#  'Struten',
#  'Kosovo',
#  'MitaII',
#  'Bagatelle Polo Club, Paris',
#  'Concordia Turnverein, St Louis',
#  'Brussels Swimming and Water Polo Club',
#  'Frankfurt Club',
# ...

# %%
#check data types
athlete_data.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
#convert datatypes if required
athlete_data['Age']= athlete_data['Age'].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-11-fdf89e78f35a> in <module>
#       1 #convert datatypes if required
# ----> 2 athlete_data['Age']= athlete_data['Age'].astype('int64')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
# ...

# %%
#Boxplot analysis
import seaborn as sns
sns.boxplot(athlete_data['Year'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#check data by yourself - that column
athlete_data[athlete_data['Year']<= 1900]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 261        133                            Franz Abb   M   NaN     NaN     NaN
# 283        150        Margaret Ives Abbott (-Dunne)   F  23.0     NaN     NaN
# 284        151  Mary Perkins Ives Abbott (Perkins-)   F  42.0     NaN     NaN
# 710        404          Louis Grenville "Lou" Abell   M  15.0     NaN     NaN
# ...        ...                                  ...  ..   ...     ...     ...
# 270473  135285                      Khristos Zoumis   M   NaN     NaN     NaN
# 270914  135481          Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270915  135481          Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270916  135481          Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270917  135481          Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#
# ...

# %%
#drop columns
athlete_data= athlete_data.drop(['Year'],axis=1)
athlete_data= athlete_data.drop(['Season'], axis=1)
athlete_data= athlete_data.drop(['Sport'], axis=1)
athlete_data= athlete_data.drop(['NOC'], axis=1)

# %%
#drop duplicates
athlete_data=athlete_data.drop_duplicates()
athlete_data.reset_index(inplace=True, drop=True)
athlete_data
# Out:
#             ID                      Name Sex  Age      Height     Weight  \
# 0            1                 A Dijiang   M   24  180.000000  80.000000
# 1            2                  A Lamusi   M   23  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M   24  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M   34  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F   21  185.000000  82.000000
# ...        ...                       ...  ..  ...         ...        ...
# 260411  135569                Andrzej ya   M   29  179.000000  89.000000
# 260412  135570                  Piotr ya   M   27  176.000000  59.000000
# 260413  135570                  Piotr ya   M   27  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M   30  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M   34  185.000000  96.000000
#
#                   Team        Games            City  \
# ...

# %%
#Remove any data if necessary
modified_data=athlete_data.drop(['Name'],axis=1)
modified_data
# Out:
#             ID Sex   Age  Height  Weight            Team  NOC        Games  \
# 0            1   M  24.0   180.0    80.0           China  CHN  1992 Summer
# 1            2   M  23.0   170.0    60.0           China  CHN  2012 Summer
# 2            3   M  24.0     NaN     NaN         Denmark  DEN  1920 Summer
# 3            4   M  34.0     NaN     NaN  Denmark/Sweden  DEN  1900 Summer
# 4            5   F  21.0   185.0    82.0     Netherlands  NED  1988 Winter
# ...        ...  ..   ...     ...     ...             ...  ...          ...
# 271111  135569   M  29.0   179.0    89.0        Poland-1  POL  1976 Winter
# 271112  135570   M  27.0   176.0    59.0          Poland  POL  2014 Winter
# 271113  135570   M  27.0   176.0    59.0          Poland  POL  2014 Winter
# 271114  135571   M  30.0   185.0    96.0          Poland  POL  1998 Winter
# 271115  135571   M  34.0   185.0    96.0          Poland  POL  2002 Winter
#
#         Year  Season            City          Sport  \
# ...

# %%
athlete_data.to_csv('athleteData_cleaned.csv')
athlete_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#group by

gk = modified_data.groupby('ID')
gk.first()

event=modified_data.groupby('Event')
event.mean()
# Out:
#                                                            ID        Age  \
# Event
# Aeronautics Mixed Aeronautics                   107506.000000  26.000000
# Alpine Skiing Men's Combined                     66242.567663  24.100352
# Alpine Skiing Men's Downhill                     65032.391753  24.083770
# Alpine Skiing Men's Giant Slalom                 66134.859283  23.330452
# Alpine Skiing Men's Slalom                       66315.715631  23.523323
# ...                                                       ...        ...
# Wrestling Women's Flyweight, Freestyle           61824.823529  24.897059
# Wrestling Women's Heavyweight, Freestyle         78103.890625  25.843750
# Wrestling Women's Light-Heavyweight, Freestyle   85739.722222  24.777778
# Wrestling Women's Lightweight, Freestyle         74470.656716  25.104478
# Wrestling Women's Middleweight, Freestyle        80116.485294  25.352941
#
#                                                     Height     Weight  \
# Event
# ...

# %%
#1 In Wrestling Women's Flyweight, Freestyle - what's the mean age of participants?
athlete_data[athlete_data['Event']=="Wrestling Women's Flyweight, Freestyle"].mean()['Age']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# 24.897058823529413

# %%
#2) Which of these are categorical & numerical variables
modified_data.dtypes
# Out:
# ID          int64
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
#3 Which participant won the maximum number of medals?
medal=athlete_data[athlete_data['Medal'] !="None"]
medal['Name'].mode()[0]
# Out:
# 'Robert Tait McKenzie'

# %%
#4 Which team had maximum Gold medals in 1992 Summer Olympics?
gold_medal= athlete_data[(athlete_data['Medal']=="Gold") & (athlete_data['Games']=="1992 Summer")]
gold_medal['Team'].mode()[0]
# Out:
# 'Unified Team'

# %% [markdown]
# ## Pandas interview question links:

# %% [markdown]
# https://www.javatpoint.com/python-pandas-interview-questions
#
#
# https://www.w3schools.com/python/pandas/pandas_quiz.asp

# %%
#Looking at pandas Series
