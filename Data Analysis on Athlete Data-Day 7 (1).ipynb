# %% [markdown]
# ## Day 3 of Pandas

# %% [markdown]
# ### <font color=blue>Some basic data steps/functions</font>

# %%
import pandas as pd
athlete_data=pd.read_csv('athlete_events.csv')

# %%
athlete_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
# find the top 5 rows of your data
athlete_data.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
# find the last 5 rows of your data
athlete_data.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# 271112  Ski Jumping Men's Large Hill, Individual   NaN
# 271113        Ski Jumping Men's Large Hill, Team   NaN
# 271114                      Bobsleigh Men's Four   NaN
# 271115                      Bobsleigh Men's Four   NaN

# %%
#drop duplicates
athlete_data=athlete_data.drop_duplicates()
athlete_data.reset_index(inplace=True, drop=True)
athlete_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 269726  135569                Andrzej ya   M  29.0   179.0    89.0
# 269727  135570                  Piotr ya   M  27.0   176.0    59.0
# 269728  135570                  Piotr ya   M  27.0   176.0    59.0
# 269729  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 269730  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 269726        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 269727          Poland  POL  2014 Winter  2014  Winter           Sochi
# 269728          Poland  POL  2014 Winter  2014  Winter           Sochi
# 269729          Poland  POL  1998 Winter  1998  Winter          Nagano
# 269730          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 269726           Luge                Luge Mixed (Men)'s Doubles   NaN
# 269727    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 269728    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 269729      Bobsleigh                      Bobsleigh Men's Four   NaN
# 269730      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [269731 rows x 15 columns]

# %%
#Checking for Null values
athlete_data.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9315
# Height     58814
# Weight     61527
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     229959
# dtype: int64

# %%
set(athlete_data['Medal'])
# Out:
# {'Bronze', 'Gold', 'Silver', nan}

# %% [markdown]
# ## Data Cleaning & Missing Value Handling

# %%
# If the number of entries is N, you have less than 5-10% missing values-- we can eliminate those rows

athlete_data=athlete_data[athlete_data['Age'].notna()]
athlete_data.reset_index(inplace=True, drop=True)


# If the number of entries is N, you have 30-50% missing values-- we can replace the rows with mean, median, mode

athlete_data['Height']=athlete_data['Height'].fillna(athlete_data['Height'].mean())
athlete_data['Weight']=athlete_data['Weight'].fillna(athlete_data['Weight'].mean())
athlete_data['Medal']=athlete_data['Medal'].fillna("None")
athlete_data.reset_index(inplace=True, drop=True)




#If the number of entries is N, you have above 70% missing values-- Use some intuition and eliminate the column


athlete_data
# Out:
# C:\Users\tanus\AppData\Local\Temp\ipykernel_18384\1972351253.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athlete_data['Height']=athlete_data['Height'].fillna(athlete_data['Height'].mean())
# C:\Users\tanus\AppData\Local\Temp\ipykernel_18384\1972351253.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athlete_data['Weight']=athlete_data['Weight'].fillna(athlete_data['Weight'].mean())
# C:\Users\tanus\AppData\Local\Temp\ipykernel_18384\1972351253.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athlete_data['Medal']=athlete_data['Medal'].fillna("None")
#             ID                      Name Sex   Age      Height     Weight  \
# 0            1                 A Dijiang   M  24.0  180.000000  80.000000
# 1            2                  A Lamusi   M  23.0  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M  24.0  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M  34.0  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F  21.0  185.000000  82.000000
# ...        ...                       ...  ..   ...         ...        ...
# 260411  135569                Andrzej ya   M  29.0  179.000000  89.000000
# 260412  135570                  Piotr ya   M  27.0  176.000000  59.000000
# 260413  135570                  Piotr ya   M  27.0  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M  30.0  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M  34.0  185.000000  96.000000
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 260411        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 260412          Poland  POL  2014 Winter  2014  Winter           Sochi
# 260413          Poland  POL  2014 Winter  2014  Winter           Sochi
# 260414          Poland  POL  1998 Winter  1998  Winter          Nagano
# 260415          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball  None
# 1                Judo              Judo Men's Extra-Lightweight  None
# 2            Football                   Football Men's Football  None
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres  None
# ...               ...                                       ...   ...
# 260411           Luge                Luge Mixed (Men)'s Doubles  None
# 260412    Ski Jumping  Ski Jumping Men's Large Hill, Individual  None
# 260413    Ski Jumping        Ski Jumping Men's Large Hill, Team  None
# 260414      Bobsleigh                      Bobsleigh Men's Four  None
# 260415      Bobsleigh                      Bobsleigh Men's Four  None
#
# [260416 rows x 15 columns]

# %%
#check columns
athlete_data.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
# check datatypes
athlete_data.dtypes
# Out:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
#convert if required
athlete_data['Age']= athlete_data['Age'].astype('int64')
# Out:
# C:\Users\tanus\AppData\Local\Temp\ipykernel_18384\3496942697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   athlete_data['Age']= athlete_data['Age'].astype('int64')

# %%
import seaborn as sns
sns.boxplot(athlete_data['Year'])
# Out:
# C:\Users\tanus\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year'>

# %%
athlete_data[athlete_data['Year']<= 1900]
# Out:
#             ID                                 Name Sex  Age      Height  \
# 3            4                 Edgar Lindenau Aabye   M   34  175.351352
# 275        150        Margaret Ives Abbott (-Dunne)   F   23  175.351352
# 276        151  Mary Perkins Ives Abbott (Perkins-)   F   42  175.351352
# 650        404          Louis Grenville "Lou" Abell   M   15  175.351352
# 2632      1538                       Vladimir Atoff   M   20  175.351352
# ...        ...                                  ...  ..  ...         ...
# 253285  131985                       Thomas Xenakis   M   21  175.351352
# 260214  135481          Jules Alexis "Louis" Zutter   M   30  175.351352
# 260215  135481          Jules Alexis "Louis" Zutter   M   30  175.351352
# 260216  135481          Jules Alexis "Louis" Zutter   M   30  175.351352
# 260217  135481          Jules Alexis "Louis" Zutter   M   30  175.351352
#
#            Weight                                            Team  NOC  \
# 3       70.711988                                  Denmark/Sweden  DEN
# 275     70.711988                                   United States  USA
# 276     70.711988                                   United States  USA
# 650     70.711988                                Vesper Boat Club  USA
# 2632    70.711988  Union des Socits Franais de Sports Athletiques  FRA
# ...           ...                                             ...  ...
# 253285  70.711988                                          Greece  GRE
# 260214  70.711988                                     Switzerland  SUI
# 260215  70.711988                                     Switzerland  SUI
# 260216  70.711988                                     Switzerland  SUI
# 260217  70.711988                                     Switzerland  SUI
#
#               Games  Year  Season    City       Sport  \
# 3       1900 Summer  1900  Summer   Paris  Tug-Of-War
# 275     1900 Summer  1900  Summer   Paris        Golf
# 276     1900 Summer  1900  Summer   Paris        Golf
# 650     1900 Summer  1900  Summer   Paris      Rowing
# 2632    1900 Summer  1900  Summer   Paris       Rugby
# ...             ...   ...     ...     ...         ...
# 253285  1896 Summer  1896  Summer  Athina  Gymnastics
# 260214  1896 Summer  1896  Summer  Athina  Gymnastics
# 260215  1896 Summer  1896  Summer  Athina  Gymnastics
# 260216  1896 Summer  1896  Summer  Athina  Gymnastics
# 260217  1896 Summer  1896  Summer  Athina  Gymnastics
#
#                                    Event   Medal
# 3            Tug-Of-War Men's Tug-Of-War    Gold
# 275              Golf Women's Individual    Gold
# 276              Golf Women's Individual    None
# 650            Rowing Men's Coxed Eights    Gold
# 2632                   Rugby Men's Rugby    Gold
# ...                                  ...     ...
# 253285    Gymnastics Men's Rope Climbing  Silver
# 260214      Gymnastics Men's Horse Vault  Silver
# 260215    Gymnastics Men's Parallel Bars  Silver
# 260216   Gymnastics Men's Horizontal Bar    None
# 260217  Gymnastics Men's Pommelled Horse    Gold
#
# [1345 rows x 15 columns]

# %%
# drop columns
athlete_data= athlete_data.drop(['Year'],axis=1)
athlete_data= athlete_data.drop(['Season'], axis=1)
athlete_data= athlete_data.drop(['Sport'], axis=1)
athlete_data= athlete_data.drop(['NOC'], axis=1)

# %%
athlete_data
# Out:
#             ID                      Name Sex  Age      Height     Weight  \
# 0            1                 A Dijiang   M   24  180.000000  80.000000
# 1            2                  A Lamusi   M   23  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M   24  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M   34  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F   21  185.000000  82.000000
# ...        ...                       ...  ..  ...         ...        ...
# 260411  135569                Andrzej ya   M   29  179.000000  89.000000
# 260412  135570                  Piotr ya   M   27  176.000000  59.000000
# 260413  135570                  Piotr ya   M   27  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M   30  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M   34  185.000000  96.000000
#
#                   Team        Games            City  \
# 0                China  1992 Summer       Barcelona
# 1                China  2012 Summer          London
# 2              Denmark  1920 Summer       Antwerpen
# 3       Denmark/Sweden  1900 Summer           Paris
# 4          Netherlands  1988 Winter         Calgary
# ...                ...          ...             ...
# 260411        Poland-1  1976 Winter       Innsbruck
# 260412          Poland  2014 Winter           Sochi
# 260413          Poland  2014 Winter           Sochi
# 260414          Poland  1998 Winter          Nagano
# 260415          Poland  2002 Winter  Salt Lake City
#
#                                            Event Medal
# 0                    Basketball Men's Basketball  None
# 1                   Judo Men's Extra-Lightweight  None
# 2                        Football Men's Football  None
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4               Speed Skating Women's 500 metres  None
# ...                                          ...   ...
# 260411                Luge Mixed (Men)'s Doubles  None
# 260412  Ski Jumping Men's Large Hill, Individual  None
# 260413        Ski Jumping Men's Large Hill, Team  None
# 260414                      Bobsleigh Men's Four  None
# 260415                      Bobsleigh Men's Four  None
#
# [260416 rows x 11 columns]

# %%
athlete_data=athlete_data.drop_duplicates()
athlete_data.reset_index(inplace=True, drop=True)
athlete_data
# Out:
#             ID                      Name Sex  Age      Height     Weight  \
# 0            1                 A Dijiang   M   24  180.000000  80.000000
# 1            2                  A Lamusi   M   23  170.000000  60.000000
# 2            3       Gunnar Nielsen Aaby   M   24  175.351352  70.711988
# 3            4      Edgar Lindenau Aabye   M   34  175.351352  70.711988
# 4            5  Christine Jacoba Aaftink   F   21  185.000000  82.000000
# ...        ...                       ...  ..  ...         ...        ...
# 260411  135569                Andrzej ya   M   29  179.000000  89.000000
# 260412  135570                  Piotr ya   M   27  176.000000  59.000000
# 260413  135570                  Piotr ya   M   27  176.000000  59.000000
# 260414  135571        Tomasz Ireneusz ya   M   30  185.000000  96.000000
# 260415  135571        Tomasz Ireneusz ya   M   34  185.000000  96.000000
#
#                   Team        Games            City  \
# 0                China  1992 Summer       Barcelona
# 1                China  2012 Summer          London
# 2              Denmark  1920 Summer       Antwerpen
# 3       Denmark/Sweden  1900 Summer           Paris
# 4          Netherlands  1988 Winter         Calgary
# ...                ...          ...             ...
# 260411        Poland-1  1976 Winter       Innsbruck
# 260412          Poland  2014 Winter           Sochi
# 260413          Poland  2014 Winter           Sochi
# 260414          Poland  1998 Winter          Nagano
# 260415          Poland  2002 Winter  Salt Lake City
#
#                                            Event Medal
# 0                    Basketball Men's Basketball  None
# 1                   Judo Men's Extra-Lightweight  None
# 2                        Football Men's Football  None
# 3                    Tug-Of-War Men's Tug-Of-War  Gold
# 4               Speed Skating Women's 500 metres  None
# ...                                          ...   ...
# 260411                Luge Mixed (Men)'s Doubles  None
# 260412  Ski Jumping Men's Large Hill, Individual  None
# 260413        Ski Jumping Men's Large Hill, Team  None
# 260414                      Bobsleigh Men's Four  None
# 260415                      Bobsleigh Men's Four  None
#
# [260416 rows x 11 columns]

# %%
#remove name
modified_data=athlete_data.drop(['Name'],axis=1)
modified_data
# Out:
#             ID Sex  Age      Height     Weight            Team        Games  \
# 0            1   M   24  180.000000  80.000000           China  1992 Summer
# 1            2   M   23  170.000000  60.000000           China  2012 Summer
# 2            3   M   24  175.351352  70.711988         Denmark  1920 Summer
# 3            4   M   34  175.351352  70.711988  Denmark/Sweden  1900 Summer
# 4            5   F   21  185.000000  82.000000     Netherlands  1988 Winter
# ...        ...  ..  ...         ...        ...             ...          ...
# 260411  135569   M   29  179.000000  89.000000        Poland-1  1976 Winter
# 260412  135570   M   27  176.000000  59.000000          Poland  2014 Winter
# 260413  135570   M   27  176.000000  59.000000          Poland  2014 Winter
# 260414  135571   M   30  185.000000  96.000000          Poland  1998 Winter
# 260415  135571   M   34  185.000000  96.000000          Poland  2002 Winter
#
#                   City                                     Event Medal
# 0            Barcelona               Basketball Men's Basketball  None
# 1               London              Judo Men's Extra-Lightweight  None
# 2            Antwerpen                   Football Men's Football  None
# 3                Paris               Tug-Of-War Men's Tug-Of-War  Gold
# 4              Calgary          Speed Skating Women's 500 metres  None
# ...                ...                                       ...   ...
# 260411       Innsbruck                Luge Mixed (Men)'s Doubles  None
# 260412           Sochi  Ski Jumping Men's Large Hill, Individual  None
# 260413           Sochi        Ski Jumping Men's Large Hill, Team  None
# 260414          Nagano                      Bobsleigh Men's Four  None
# 260415  Salt Lake City                      Bobsleigh Men's Four  None
#
# [260416 rows x 10 columns]

# %%
modified_data=modified_data.drop_duplicates()
modified_data
modified_data.to_csv('modifiedData_cleaned.csv')

# %%
athlete_data
athlete_data.to_csv('athleteData_cleaned.csv')

# %%
#group by

gk = modified_data.groupby('ID')
gk.first()

event=modified_data.groupby('Event')
event.mean()
# Out:
#                                                            ID        Age  \
# Event
# Aeronautics Mixed Aeronautics                   107506.000000  26.000000
# Alpine Skiing Men's Combined                     66266.480634  24.100352
# Alpine Skiing Men's Downhill                     65133.152705  24.083770
# Alpine Skiing Men's Giant Slalom                 66275.726064  23.330452
# Alpine Skiing Men's Slalom                       66410.934824  23.523323
# ...                                                       ...        ...
# Wrestling Women's Flyweight, Freestyle           61824.823529  24.897059
# Wrestling Women's Heavyweight, Freestyle         78103.890625  25.843750
# Wrestling Women's Light-Heavyweight, Freestyle   85739.722222  24.777778
# Wrestling Women's Lightweight, Freestyle         74470.656716  25.104478
# Wrestling Women's Middleweight, Freestyle        80116.485294  25.352941
#
#                                                     Height     Weight
# Event
# Aeronautics Mixed Aeronautics                   175.351352  70.711988
# Alpine Skiing Men's Combined                    178.692663  79.701250
# Alpine Skiing Men's Downhill                    177.091505  76.413343
# Alpine Skiing Men's Giant Slalom                176.393959  74.695257
# Alpine Skiing Men's Slalom                      176.663414  74.674048
# ...                                                    ...        ...
# Wrestling Women's Flyweight, Freestyle          156.014706  48.661765
# Wrestling Women's Heavyweight, Freestyle        170.890625  73.296875
# Wrestling Women's Light-Heavyweight, Freestyle  169.277778  69.666667
# Wrestling Women's Lightweight, Freestyle        162.537313  56.880597
# Wrestling Women's Middleweight, Freestyle       165.367647  63.584000
#
# [757 rows x 4 columns]

# %%
## check all columns of modified data dataframe

# %% [markdown]
# Exploratory Data Analysis: (Only for ML)
# Data Normalization: Data Normalization could also be a typical practice in machine learning which consists of transforming numeric columns to a standard scale. In machine learning, some feature values differ from others multiple times. The features with higher values will dominate the learning process.
#
# Min-Max Scaler
#
# Standard Scaler

# %%
##
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

scaler= MinMaxScaler()
dftest= pd.DataFrame({'a':[1,2,3,4,5],
                     'b':[100,500,2500,12500,62500]})
dftest
dftest[['a','b']]=scaler.fit_transform(dftest[['a','b']])
dftest
# Out:
#       a         b
# 0  0.00  0.000000
# 1  0.25  0.006410
# 2  0.50  0.038462
# 3  0.75  0.198718
# 4  1.00  1.000000

# %% [markdown]
# Quick Question?
# 1) In Wrestling Women's Flyweight, Freestyle - what's the mean age of participants?
#
#
# 2) Which of these are categorical & numerical variables
#
#
# 3) Which participant won the maximum number of medals?
#
#
# 4) Which team had maximum Gold medals in 1992 Summer Olympics?

# %%
#1
athlete_data[athlete_data['Event']=="Wrestling Women's Flyweight, Freestyle"].mean()['Age']
# Out:
# C:\Users\tanus\AppData\Local\Temp\ipykernel_18384\941809491.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   athlete_data[athlete_data['Event']=="Wrestling Women's Flyweight, Freestyle"].mean()['Age']
# 24.897058823529413

# %% [markdown]
# #2

# %%
modified_data.dtypes
# Out:
# ID          int64
# Sex        object
# Age         int64
# Height    float64
# Weight    float64
# Team       object
# Games      object
# City       object
# Event      object
# Medal      object
# dtype: object

# %%
#3
medal=athlete_data[athlete_data['Medal'] !="None"]
medal['Name'].mode()[0]
# Out:
# 'Michael Fred Phelps, II'

# %%
#4

gold_medal= athlete_data[(athlete_data['Medal']=="Gold") & (athlete_data['Games']=="1992 Summer")]
gold_medal['Team'].mode()[0]
# Out:
# 'Unified Team'
