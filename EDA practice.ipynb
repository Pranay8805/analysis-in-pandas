# %%
##import data
import pandas as pd
data=pd.read_csv('heart.csv')
data

# downlosd from https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
# display head, tail, describe, info,rows, columns, no. of unique elemnets in each column etc
data.head()
data.tail()
data.describe()
data.info
data.columns
len(data)
#list(set(list(data.coulumn_name)))
# Out:
# 1025

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
data.info
# Out:
# <bound method DataFrame.info of       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]>

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
len(data)
# Out:
# 1025

# %%
list(set(list(data.target)))
# Out:
# [0, 1]

# %%
## check duplicates and drop them +reset index
data=data.drop_duplicates()
data.reset_index(inplace=True, drop=True)
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   68    0   2       120   211    0        0      115      0      1.5
# 298   44    0   2       108   141    0        1      175      0      0.6
# 299   52    1   0       128   255    0        1      161      1      0.0
# 300   59    1   3       160   273    0        0      125      0      0.0
# 301   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# 2        0   0     3       0
# 3        2   1     3       0
# 4        1   3     2       0
# ..     ...  ..   ...     ...
# 297      1   0     2       1
# 298      1   0     2       1
# 299      2   1     3       0
# 300      2   0     2       0
# 301      1   1     3       0
#
# [302 rows x 14 columns]

# %%
## check NaN values in each column and filter rows based on them
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# check each datatype & find if it makes sense. Use astype/to_numeric to convert
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
## search for outliers using box plots
import seaborn as sns
sns.boxplot(data['thal'])
# Out:
# <AxesSubplot: >

# %%
# remove above 180--trestbps, --500:chol less than 80 --thalach, >5--oldpeak >27 --ca, <0.5--thal

#data[data['trestbps']>180]
#data=data[data['ca']>0.5]
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   68    0   2       120   211    0        0      115      0      1.5
# 298   44    0   2       108   141    0        1      175      0      0.6
# 299   52    1   0       128   255    0        1      161      1      0.0
# 300   59    1   3       160   273    0        0      125      0      0.0
# 301   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# 2        0   0     3       0
# 3        2   1     3       0
# 4        1   3     2       0
# ..     ...  ..   ...     ...
# 297      1   0     2       1
# 298      1   0     2       1
# 299      2   1     3       0
# 300      2   0     2       0
# 301      1   1     3       0
#
# [302 rows x 14 columns]

# %%
# try finding correlation between columns- and eliminate if representing same info
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# target   -0.221476 -0.283609  0.432080 -0.146269 -0.081437 -0.026826
#
#            restecg   thalach     exang   oldpeak     slope        ca  \
# age      -0.111590 -0.395235  0.093216  0.206040 -0.164124  0.302261
# sex      -0.060351 -0.046439  0.143460  0.098322 -0.032990  0.113060
# cp        0.041561  0.293367 -0.392937 -0.146692  0.116854 -0.195356
# trestbps -0.115367 -0.048023  0.068526  0.194600 -0.122873  0.099248
# chol     -0.147602 -0.005308  0.064099  0.050086  0.000417  0.086878
# fbs      -0.083081 -0.007169  0.024729  0.004514 -0.058654  0.144935
# restecg   1.000000  0.041210 -0.068807 -0.056251  0.090402 -0.083112
# thalach   0.041210  1.000000 -0.377411 -0.342201  0.384754 -0.228311
# exang    -0.068807 -0.377411  1.000000  0.286766 -0.256106  0.125377
# oldpeak  -0.056251 -0.342201  0.286766  1.000000 -0.576314  0.236560
# slope     0.090402  0.384754 -0.256106 -0.576314  1.000000 -0.092236
# ca       -0.083112 -0.228311  0.125377  0.236560 -0.092236  1.000000
# thal     -0.010473 -0.094910  0.205826  0.209090 -0.103314  0.160085
# target    0.134874  0.419955 -0.435601 -0.429146  0.343940 -0.408992
#
#               thal    target
# age       0.065317 -0.221476
# sex       0.211452 -0.283609
# cp       -0.160370  0.432080
# trestbps  0.062870 -0.146269
# chol      0.096810 -0.081437
# fbs      -0.032752 -0.026826
# restecg  -0.010473  0.134874
# thalach  -0.094910  0.419955
# exang     0.205826 -0.435601
# oldpeak   0.209090 -0.429146
# slope    -0.103314  0.343940
# ca        0.160085 -0.408992
# thal      1.000000 -0.343101
# target   -0.343101  1.000000

# %%
# assume target is the target variable here-- find out the top 3 highest correlated features & only keep them
new_df= data[['cp','restecg','slope','target']]
new_df
# Out:
#      cp  restecg  slope  target
# 0     0        1      2       0
# 1     0        0      0       0
# 2     0        1      0       0
# 3     0        1      2       0
# 4     0        1      1       0
# ..   ..      ...    ...     ...
# 297   2        0      1       1
# 298   2        1      1       1
# 299   0        1      2       0
# 300   3        0      2       0
# 301   0        1      1       0
#
# [302 rows x 4 columns]

# %%
# find out average age of people having a cp >1
data[data['cp']>1]['age'].mean()
# Out:
# 54.15596330275229

# %%
## try doing seaborn-- all plots
import seaborn as sns
## plot a catplot between age/cholestrol -- hue= cp col=sex- kind='bar'-- if you get an inconclusive data- try grouping rows
##-- and creating a separate column called age range

g=sns.catplot(x="age", y="chol", hue="target", col="sex", data=data)
# Out:
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data
# C:\Users\PRANAY\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:292: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   sub_data.loc[:, self.cat_axis] = adjusted_data

# %%
lst=[]
for age in data['age']:
    if age <=40:
        lst.append("Upto 40")
    elif age>=41 and age<=50:
        lst.append("41-50")
    elif age>=51 and age<=60:
        lst.append("51-60")
    elif age>=61 and age<=70:
        lst.append("61-70")
    else:
        lst.append("Above 71")
data['Age Range']= lst
# Out:
# C:\Users\PRANAY\AppData\Local\Temp\ipykernel_17040\342379160.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age Range']= lst

# %%
## which age range has highest fbs & cholestrol

sns.barplot(x="Age Range", y="fbs", data=data)
# Out:
# <AxesSubplot: xlabel='Age Range', ylabel='fbs'>

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   68    0   2       120   211    0        0      115      0      1.5
# 298   44    0   2       108   141    0        1      175      0      0.6
# 299   52    1   0       128   255    0        1      161      1      0.0
# 300   59    1   3       160   273    0        0      125      0      0.0
# 301   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target Age Range
# 0        2   2     3       0     51-60
# 1        0   0     3       0     51-60
# 2        0   0     3       0     61-70
# 3        2   1     3       0     61-70
# 4        1   3     2       0     61-70
# ..     ...  ..   ...     ...       ...
# 297      1   0     2       1     61-70
# 298      1   0     2       1     41-50
# 299      2   1     3       0     51-60
# 300      2   0     2       0     51-60
# 301      1   1     3       0     51-60
#
# [302 rows x 15 columns]

# %%
## try plots again on reduced features

# %%
## sort values by increasing thalach

# %%
## be creative! Any specific analysis you want to come up with?

# %%
# try converting categorical to numerical/ scaling data if required

# %%
s= data.groupby(['sex','Age Range'])
s.mean()
# Out:
#                      age        cp    trestbps        chol       fbs  \
# sex Age Range
# 0   41-50      45.045455  1.090909  122.000000  235.136364  0.045455
#     51-60      55.657143  1.028571  136.171429  270.057143  0.200000
#     61-70      64.103448  0.931034  140.551724  284.517241  0.103448
#     Above 71   72.600000  1.200000  128.400000  236.400000  0.200000
#     Upto 40    36.800000  1.400000  121.600000  205.400000  0.000000
# 1   41-50      45.018519  0.962963  124.981481  237.185185  0.092593
#     51-60      55.755319  0.872340  132.489362  240.297872  0.202128
#     61-70      65.045455  0.909091  135.818182  245.795455  0.204545
#     Above 71   77.000000  0.000000  125.000000  304.000000  0.000000
#     Upto 40    36.846154  1.307692  128.000000  218.692308  0.000000
#
#                 restecg     thalach     exang   oldpeak     slope        ca  \
# sex Age Range
# 0   41-50      0.590909  158.500000  0.227273  0.509091  1.363636  0.090909
#     51-60      0.485714  149.571429  0.285714  0.880000  1.485714  0.485714
#     61-70      0.551724  146.793103  0.206897  1.265517  1.310345  1.034483
#     Above 71   0.800000  130.800000  0.200000  0.660000  1.600000  0.800000
#     Upto 40    1.000000  175.000000  0.000000  0.420000  1.800000  0.000000
# 1   41-50      0.574074  158.666667  0.203704  0.675926  1.555556  0.481481
#     51-60      0.510638  147.202128  0.436170  1.213830  1.340426  0.861702
#     61-70      0.386364  134.590909  0.431818  1.518182  1.204545  1.136364
#     Above 71   0.000000  162.000000  1.000000  0.000000  2.000000  3.000000
#     Upto 40    0.615385  167.153846  0.384615  1.038462  1.538462  0.307692
#
#                    thal    target
# sex Age Range
# 0   41-50      2.045455  0.954545
#     51-60      2.085714  0.685714
#     61-70      2.275862  0.586207
#     Above 71   2.000000  1.000000
#     Upto 40    2.000000  1.000000
# 1   41-50      2.277778  0.592593
#     51-60      2.457447  0.425532
#     61-70      2.409091  0.295455
#     Above 71   2.000000  0.000000
#     Upto 40    2.538462  0.538462
